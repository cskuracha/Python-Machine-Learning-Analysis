# %% [markdown]
# # Linear Regression
# ### Learn to implement the model function f for linear regression with one variable

# %% [markdown]
# #### Importing dependencies

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("classic")

# %%
#plt.style.available

# %%
x_train = np.array([1.0,2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %% [markdown]
# #### Number of training examples

# %%
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is 2

# %% [markdown]
# #### Training Examples

# %%
i = 0
x_i = x_train[i]
y_i = y_train[i]
print(f"(x_0, y_0) = ({x_i},{y_i})")
i = 1
x_i = x_train[i]
y_i = y_train[i]
print(f"(x_1, y_1) = ({x_i},{y_i})")
# Out:
# (x_0, y_0) = (1.0,300.0)
# (x_1, y_1) = (2.0,500.0)

# %% [markdown]
# #### Plotting the data

# %%
plt.scatter(x_train, y_train, marker = "x", c = "r")
plt.title("House Pricing")
plt.ylabel("Price ( in 1000 dollar)")
plt.xlabel("Size (in sqft)")
plt.show()

# %% [markdown]
# #### Model Function

# %%
(w,b) = (100,100)
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %% [markdown]
# #### Compute models

# %%
def compute_model_output(x,w,b):
    """Compute the prediction of a linear model"""
    m = x.shape[0]
    print(f"Value of m is {m}")
    f_wb = np.zeros(m)
    print(f"Initial value of f_wb is {f_wb}")
    for i in range(m):
        f_wb[i] = w * x[i] + b
        print(f"Value of f_wb for {i} is {f_wb[i]}")
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b)
print(f"Value of tmp_f_wb: {tmp_f_wb}")
plt.plot(x_train, tmp_f_wb, c = 'b', label = "Our Prediction")
plt.scatter(x_train, y_train, marker = "x", c = "r", label = "Actual Values")
plt.title("Housing Prices")
plt.ylabel("Price")
plt.xlabel("Size")
plt.legend()
plt.show()
# Out:
# Value of m is 2
# Initial value of f_wb is [0. 0.]
# Value of f_wb for 0 is 200.0
# Value of f_wb for 1 is 300.0
# Value of tmp_f_wb: [200. 300.]

# %%
tmp_f_wb = compute_model_output(x_train, 200, 200)
print(f"Value of tmp_f_wb : {tmp_f_wb}")
plt.plot(x_train, tmp_f_wb, c = 'b', label = "Our Prediction")
plt.scatter(x_train, y_train, marker = "x", c = "r", label = "Actual Values")
plt.title("Housing Prices")
plt.xlabel("Size")
plt.ylabel("Price")
plt.legend()
plt.show()
# Out:
# Value of m is 2
# Initial value of f_wb is [0. 0.]
# Value of f_wb for 0 is 400.0
# Value of f_wb for 1 is 600.0
# Value of tmp_f_wb : [400. 600.]

# %%
tmp_f_wb = compute_model_output(x_train, 200, 100)
print(f"Value of tmp_f_wb : {tmp_f_wb}")
plt.plot(x_train, tmp_f_wb, c = 'b', label = "Our Prediction")
plt.scatter(x_train, y_train, marker = "x", c = "r", label = "Actual Values")
plt.title("Housing Prices")
plt.xlabel("Size")
plt.ylabel("Price")
plt.legend()
plt.show()
# Out:
# Value of m is 2
# Initial value of f_wb is [0. 0.]
# Value of f_wb for 0 is 300.0
# Value of f_wb for 1 is 500.0
# Value of tmp_f_wb : [300. 500.]
