# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# %%
features, labels = datasets.make_blobs(n_samples = 10, n_features = 2, centers = [[2,2],[10,10]], cluster_std = 0.2)

# %%
labels
# Out:
# array([0, 0, 0, 1, 1, 0, 1, 1, 0, 1])

# %%
features
# Out:
# array([[ 2.1260342 ,  1.81252388],
#        [ 1.82968551,  2.28522299],
#        [ 1.97447494,  2.00730276],
#        [ 9.81285172,  9.93469813],
#        [ 9.83835616, 10.1452853 ],
#        [ 2.06503811,  1.86708419],
#        [10.15661758,  9.68000886],
#        [10.04233853,  9.47060372],
#        [ 2.02971945,  1.8536106 ],
#        [ 9.79432492, 10.44260788]])

# %%
sns.scatterplot(x= [1,2,3], y = [100,200,300], hue = [1,0,2])
# Out:
# <Axes: >

# %%
sns.scatterplot(x = features[:,0], y= features[:,1], hue = labels)
# Out:
# <Axes: >
