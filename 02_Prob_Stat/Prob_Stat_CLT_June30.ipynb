# %% [markdown]
# ## Central Limit Theorem

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
df = pd.read_csv("weight-height.csv")
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df_height = df['Height']
df_height
# Out:
# 0       73.847017
# 1       68.781904
# 2       74.110105
# 3       71.730978
# 4       69.881796
#           ...
# 9995    66.172652
# 9996    67.067155
# 9997    63.867992
# 9998    69.034243
# 9999    61.944246
# Name: Height, Length: 10000, dtype: float64

# %%
df_height.mean()
# Out:
# 66.36755975482124

# %%
df_height.sample(5)
# Out:
# 4211    68.444967
# 7640    60.150031
# 6898    60.274234
# 202     75.140821
# 9665    60.886253
# Name: Height, dtype: float64

# %%
np.mean(df_height.sample(5))
# Out:
# 66.04243511509192

# %%
sample_5 = [np.mean(df_height.sample(5)) for _ in range(10000)]

# %%
sns.histplot(sample_5)
# Out:
# <Axes: ylabel='Count'>

# %%
np.mean(sample_5)
# Out:
# 66.34389897763828

# %%
sample_20 = [np.mean(df_height.sample(20)) for _ in range(10000)]
print(np.mean(sample_20))
sns.histplot(sample_20)
# Out:
# 66.36703367956515
# <Axes: ylabel='Count'>

# %%
np.std(sample_5), np.std(sample_20)
# Out:
# (1.7167381120356702, 0.8596614188470821)

# %%
#Standard Error (population)
df_height.std()/np.sqrt(5), df_height.std()/np.sqrt(20)
# Out:
# (1.7206668846781923, 0.8603334423390961)

# %%
sample_30 = [np.mean(df_height.sample(30)) for _ in range(10000)]
print(np.mean(sample_30))
sns.histplot(sample_30)
# Out:
# 66.3708847858474
# <Axes: ylabel='Count'>

# %%
np.std(sample_30), df_height.std()/np.sqrt(30)
# Out:
# (0.6965464356449956, 0.702459314127653)

# %%
sample_300 = [np.mean(df_height.sample(300)) for _ in range(10000)]
print(np.mean(sample_300))
sns.histplot(sample_300)
# Out:
# 66.36655674114063
# <Axes: ylabel='Count'>

# %%
np.std(sample_300), df_height.std()/np.sqrt(300)
# Out:
# (0.2168199471261994, 0.22213713962430787)

# %% [markdown]
# ![image.png](attachment:42969b0b-16cb-44f6-9238-36ba51888f45.png)

# %%
mean_pop = 122
std_pop = 10
n = 16
mean_sample = mean_pop
std_sample = std_pop/np.sqrt(n)

# %%
mean_sample, std_sample
# Out:
# (122, 2.5)

# %%
z = (125-122)/std_sample
1 - norm.cdf(z)
# Out:
# 0.11506967022170822

# %% [markdown]
# ![image.png](attachment:9687f0e9-a109-4d43-a6e5-7363a330d777.png)

# %%
mean_pop = 1000
std_pop = 200
n = 4
mean_sample = 1000
std_sample = std_pop/np.sqrt(n)
mean_sample, std_sample
# Out:
# (1000, 100.0)

# %%
z = (1110 - 1000)/ std_sample
1 - norm.cdf(z)
# Out:
# 0.13566606094638267

# %% [markdown]
# ![image.png](attachment:59e56669-915e-4ca5-ab09-f2872808f2b0.png)

# %%
mean_pop = 80
std_pop = 15
n = 50
mean_sample = mean_pop
std_sample = std_pop/np.sqrt(n)
z = (75-80)/std_sample
norm.cdf(z)
# Out:
# 0.009211062727049501

# %% [markdown]
# ### Confidence Intervals

# %%
norm.ppf(0.025), norm.ppf(0.5+0.475)
# Out:
# (-1.9599639845400545, 1.959963984540054)

# %% [markdown]
# ![image.png](attachment:8ebde800-f1cc-4fff-bb2c-e1743c656871.png)

# %%
mean_sample = 65
n = 100
std_pop = 2.5
# 90% of confidence interval
std_sample = std_pop / np.sqrt(n)
mean_sample + norm.ppf(0.025) * std_sample, mean_sample + norm.ppf(0.5+0.475) * std_sample
# Out:
# (64.51000900386498, 65.48999099613502)

# %% [markdown]
# ![image.png](attachment:3fb211c2-6c37-4561-bad0-e56a9bf5cbcb.png)

# %%
mean_sample = 10.5
std_pop = 2
n = 100
std_sample = std_pop/np.sqrt(n)

mean_sample + norm.ppf(0.025)* std_sample, mean_sample + norm.ppf(0.5+0.475)*std_sample
# Out:
# (10.108007203091988, 10.89199279690801)

# %%
norm.interval(0.95, loc = mean_sample, scale = std_sample)
# Out:
# (10.10800720309199, 10.89199279690801)

# %% [markdown]
# ![image.png](attachment:37439979-2ce8-4b6e-b977-1237e587eb46.png)

# %%
mean_sample = 45
std_pop = 10
n = 80
std_sample = 10/np.sqrt(n)
mean_sample + norm.ppf(0.05)* std_sample, mean_sample + norm.ppf(0.5+0.45)*std_sample
# Out:
# (43.16099773854971, 46.83900226145029)

# %%
norm.interval(0.90,loc = mean_sample, scale = std_sample)
# Out:
# (43.16099773854971, 46.83900226145029)

# %% [markdown]
# ![image.png](attachment:ede95e95-8541-4b33-a9f3-2b6c33f2e2ca.png)

# %%
mean_sample = 6
std_pop = 2
n = 25
std_sample = 2/np.sqrt(n)
mean_sample + norm.ppf(0.50-(0.99/2))* std_sample, mean_sample + norm.ppf(0.50+(0.99/2))*std_sample
# Out:
# (4.96966827858044, 7.03033172141956)

# %%
norm.interval(0.99,loc = mean_sample, scale = std_sample)
# Out:
# (4.96966827858044, 7.03033172141956)
